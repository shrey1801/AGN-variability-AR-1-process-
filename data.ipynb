# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import scipy
import os
px=pd.read_excel('data.xlsx',sheet_name='Sheet1')
a=px.as_matrix()
k=1.125;
c=0;d=0;e=0;
for i in range( 0 ,5295):
    if(a[i,20]<=1):
        c=c+1
    elif(a[i,20]>1 and a[i,20]<=k):
        d=d+1    
    else:
        e=e+1
labels='less than 1','between 1 and 1.125','greater than 1.125'
size=[c,d,e]
colors='green','blue','red'
plt.pie(size,labels=labels,colors=colors,autopct='%1.1f%%')
plt.title('Pie Chart -> total target = 5295')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
# Text(0.5, 1.0, 'Pie Chart -> total target = 5295')

# %%
import os
print (os.getcwd())
print(os.listdir())
os.chdir('downloads')
# Out:
# /Users/shrey/Downloads
# ...

# %%
plt.scatter(a[:,20],a[:,21],color='g',label='correlation coefficient (r)=0.87')
r=scipy.stats.pearsonr(a[:,20],a[:,21])
print(r)
plt.xlabel('amplitude of variability in g band (unitless) ' )
plt.ylabel(' amplitude of variability in r band (unitless)')
plt.title(' Amplitude of variability in r band vs amplitude of variability in g band  ')
plt.legend()
# Out:
# (0.07270387509939477, 1.1824682234696257e-07)

# %%
print(np.std(a[1:1800,20]))
# Out:
# 0.21814454267653405

# %%
#ax.scatter(-1,.3,s=20,color='blue')
plt.hist(a[:,20],bins=40,color='green',histtype=u'step')
plt.axvline(x=1.22,ymax=0.95,linewidth=2,color='g',label='data covered by r dependent fluctuation of M')
plt.axvline(x=1.12,ymax=0.95,linewidth=6,color='g')
plt.axvline(x=1.02,ymax=0.41,linewidth=2,color='r',label= 'data covered by equal perturbations')
plt.axvline(x=1.03,ymax=0.41,linewidth=2,color='r')
plt.axvline(x=1.04,ymax=0.41,linewidth=2,color='r')


#plt.axvline(x=1,color='black')
#plt.axvline (x=1.04,color='black')
#plt.axvline(x=1.20,ymax=1,color='black')
plt.legend()
plt.xlabel('ratio of amplitude of variability in g band and r band (unitless)')
plt.ylabel('N')
plt.title('Histogram showing ratio of amplitude of variability in two bands')
plt.show()

# %%
plt.hist(a[:,20],bins=40)
# Out:
# (array([3.000e+00, 2.000e+00, 1.300e+01, 7.200e+01, 8.810e+02, 1.997e+03,
#         1.545e+03, 5.660e+02, 1.330e+02, 3.400e+01, 1.400e+01, 1.100e+01,
#         6.000e+00, 4.000e+00, 2.000e+00, 2.000e+00, 0.000e+00, 1.000e+00,
#         2.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([0.21518389, 0.3802157 , 0.5452475 , 0.71027931, 0.87531112,
#         1.04034292, 1.20537473, 1.37040654, 1.53543834, 1.70047015,
#         1.86550196, 2.03053376, 2.19556557, 2.36059738, 2.52562918,
#         2.69066099, 2.8556928 , 3.0207246 , 3.18575641, 3.35078822,
#         3.51582002, 3.68085183, 3.84588364, 4.01091544, 4.17594725,
#         4.34097906, 4.50601086, 4.67104267, 4.83607448, 5.00110628,
# ...
